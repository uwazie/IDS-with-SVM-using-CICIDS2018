# %%
import pandas as pd

# %%
Bot=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\03-02-2018.csv")
BruteForce=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\02-14-2018.csv")
DDoS=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\02-21-2018.csv")
DoS=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\02-15-2018.csv")
DoS1=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\Cleaned files\02-16-2018.csv")
Infiltration=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\Cleaned files\02-28-2018.csv")
Infiltration1=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\Cleaned files\03-01-2018.csv")
SQL1=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\02-23-2018.csv")
SQL=pd.read_csv(r"C:\Users\Dell\Desktop\CICIDS2018\02-22-2018.csv")

# %%
AllAttacks=pd.concat([Bot,BruteForce,DDoS,DoS,DoS1,Infiltration,Infiltration1,SQL1,SQL],ignore_index=True)

# %%
AllAttacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8284195 entries, 0 to 8284194
# Data columns (total 80 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Dst Port           int64
#  1   Protocol           int64
#  2   Timestamp          object
#  3   Flow Duration      int64
#  4   Tot Fwd Pkts       int64
#  5   Tot Bwd Pkts       int64
#  6   TotLen Fwd Pkts    int64
#  7   TotLen Bwd Pkts    float64
#  8   Fwd Pkt Len Max    int64
#  9   Fwd Pkt Len Min    int64
#  10  Fwd Pkt Len Mean   float64
#  11  Fwd Pkt Len Std    float64
#  12  Bwd Pkt Len Max    int64
#  13  Bwd Pkt Len Min    int64
#  14  Bwd Pkt Len Mean   float64
#  15  Bwd Pkt Len Std    float64
#  16  Flow Byts/s        float64
#  17  Flow Pkts/s        float64
#  18  Flow IAT Mean      float64
#  19  Flow IAT Std       float64
#  20  Flow IAT Max       float64
#  21  Flow IAT Min       float64
#  22  Fwd IAT Tot        float64
#  23  Fwd IAT Mean       float64
# ...

# %%
AllAttacks['Label'].value_counts()
# Out:
# Benign                      6112151
# DDOS attack-HOIC             686012
# DoS attacks-Hulk             461912
# Bot                          286191
# FTP-BruteForce               193360
# SSH-Bruteforce               187589
# Infilteration                161934
# DoS attacks-SlowHTTPTest     139890
# DoS attacks-GoldenEye         41508
# DoS attacks-Slowloris         10990
# DDOS attack-LOIC-UDP           1730
# Brute Force -Web                611
# Brute Force -XSS                230
# SQL Injection                    87
# Name: Label, dtype: int64

# %%
AllAttacks=AllAttacks.sample(frac=.025)

# %%
AllAttacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207105 entries, 352042 to 1259943
# Data columns (total 80 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           207105 non-null  int64
#  1   Protocol           207105 non-null  int64
#  2   Timestamp          207105 non-null  object
#  3   Flow Duration      207105 non-null  int64
#  4   Tot Fwd Pkts       207105 non-null  int64
#  5   Tot Bwd Pkts       207105 non-null  int64
#  6   TotLen Fwd Pkts    207105 non-null  int64
#  7   TotLen Bwd Pkts    207105 non-null  float64
#  8   Fwd Pkt Len Max    207105 non-null  int64
#  9   Fwd Pkt Len Min    207105 non-null  int64
#  10  Fwd Pkt Len Mean   207105 non-null  float64
#  11  Fwd Pkt Len Std    207105 non-null  float64
#  12  Bwd Pkt Len Max    207105 non-null  int64
#  13  Bwd Pkt Len Min    207105 non-null  int64
#  14  Bwd Pkt Len Mean   207105 non-null  float64
# ...

# %%
AllAttacks['Label'].value_counts()
# Out:
# Benign                      152648
# DDOS attack-HOIC             17320
# DoS attacks-Hulk             11496
# Bot                           7097
# SSH-Bruteforce                4770
# FTP-BruteForce                4769
# Infilteration                 4057
# DoS attacks-SlowHTTPTest      3571
# DoS attacks-GoldenEye         1011
# DoS attacks-Slowloris          289
# DDOS attack-LOIC-UDP            53
# Brute Force -Web                17
# Brute Force -XSS                 6
# SQL Injection                    1
# Name: Label, dtype: int64

# %%
null_columns=AllAttacks.columns[AllAttacks.isnull().any()]
AllAttacks[null_columns].isnull().sum()
# Out:
# Flow Byts/s    576
# dtype: int64

# %%
Nullvalues=AllAttacks[AllAttacks.isnull().any(1)]
Nullvalues['Label'].value_counts()
# Out:
# Benign           556
# Infilteration     20
# Name: Label, dtype: int64

# %%
AllAttacks=AllAttacks.dropna(axis=0, how='any')

# %%
AllAttacks['Label'].value_counts()
# Out:
# Benign                      152092
# DDOS attack-HOIC             17320
# DoS attacks-Hulk             11496
# Bot                           7097
# SSH-Bruteforce                4770
# FTP-BruteForce                4769
# Infilteration                 4037
# DoS attacks-SlowHTTPTest      3571
# DoS attacks-GoldenEye         1011
# DoS attacks-Slowloris          289
# DDOS attack-LOIC-UDP            53
# Brute Force -Web                17
# Brute Force -XSS                 6
# SQL Injection                    1
# Name: Label, dtype: int64

# %%
zero_cols = [col for col, is_zero in ((AllAttacks == 0).sum() == AllAttacks.shape[0]).items() if is_zero]
zero_cols
# Out:
# ['Bwd PSH Flags',
#  'Bwd URG Flags',
#  'Fwd Byts/b Avg',
#  'Fwd Pkts/b Avg',
#  'Fwd Blk Rate Avg',
#  'Bwd Byts/b Avg',
#  'Bwd Pkts/b Avg',
#  'Bwd Blk Rate Avg']

# %%
AllAttacks.drop(zero_cols, axis=1, inplace=True)

# %%
AllAttacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206529 entries, 352042 to 1259943
# Data columns (total 72 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           206529 non-null  int64
#  1   Protocol           206529 non-null  int64
#  2   Timestamp          206529 non-null  object
#  3   Flow Duration      206529 non-null  int64
#  4   Tot Fwd Pkts       206529 non-null  int64
#  5   Tot Bwd Pkts       206529 non-null  int64
#  6   TotLen Fwd Pkts    206529 non-null  int64
#  7   TotLen Bwd Pkts    206529 non-null  float64
#  8   Fwd Pkt Len Max    206529 non-null  int64
#  9   Fwd Pkt Len Min    206529 non-null  int64
#  10  Fwd Pkt Len Mean   206529 non-null  float64
#  11  Fwd Pkt Len Std    206529 non-null  float64
#  12  Bwd Pkt Len Max    206529 non-null  int64
#  13  Bwd Pkt Len Min    206529 non-null  int64
#  14  Bwd Pkt Len Mean   206529 non-null  float64
# ...

# %%
AllAttacks.drop('Timestamp', axis=1, inplace=True)

# %%
AllAttacks["Label"].replace({"Benign": 7, "Bot": 4, "FTP-BruteForce": 3, "SSH-Bruteforce": 3, "DDOS attack-HOIC": 1, "DDOS attack-LOIC-UDP": 1, "DoS attacks-Hulk": 2, "DoS attacks-SlowHTTPTest": 2, "DoS attacks-Slowloris": 2, "DoS attacks-GoldenEye": 2, "Infilteration": 5, "Brute Force -Web": 6, "Brute Force -XSS": 6, "SQL Injection": 6}, inplace=True)

# %%
x, y = AllAttacks.iloc[:, :-1], AllAttacks.iloc[:, [-1]]

# %%
del Bot
del BruteForce
del DDoS
del DoS
del DoS1
del Infiltration
del Infiltration1
del SQL1
del SQL
del AllAttacks

# %%
import numpy as np

# %%
np. any(np.isnan(x))
# Out:
# False

# %%
np. all(np.isfinite(x))
# Out:
# False

# %%
np.where(np.isinf(x))
# Out:
# (array([   158,    158,    750,    750,   1693,   1693,   1912,   1912,
#           2045,   2045,   2224,   2224,   4088,   4088,   5192,   5192,
#           5202,   5202,   5705,   5705,   6256,   6256,   7099,   7099,
#           7751,   7751,   8001,   8001,   8140,   8140,   8944,   8944,
#           9318,   9318,  10202,  10202,  10601,  10601,  10996,  10996,
#          11464,  11464,  11587,  11587,  12167,  12167,  12181,  12181,
#          13228,  13228,  15848,  15848,  17037,  17037,  17158,  17158,
#          17319,  17319,  17534,  17534,  19004,  19004,  19277,  19277,
#          20439,  20439,  21238,  21238,  22192,  22192,  22533,  22533,
#          22632,  22632,  23102,  23102,  23104,  23104,  23441,  23441,
#          23665,  23665,  23722,  23722,  23767,  23767,  24278,  24278,
#          24651,  24651,  25993,  25993,  27909,  27909,  29106,  29106,
#          29353,  29353,  29879,  29879,  30853,  30853,  30872,  30872,
# ...

# %%
x[x==np.inf]=np.nan
x.fillna(x.mean(), inplace=True)

# %%
np. all(np.isfinite(x))
# Out:
# True

# %%
np. any(np.isnan(y))
# Out:
# False

# %%
np. all(np.isfinite(y))
# Out:
# True

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206529 entries, 352042 to 1259943
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Label   206529 non-null  int64
# dtypes: int64(1)
# memory usage: 3.2 MB

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF = RandomForestClassifier(random_state=0, n_jobs=-1)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206529 entries, 352042 to 1259943
# Data columns (total 70 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           206529 non-null  int64
#  1   Protocol           206529 non-null  int64
#  2   Flow Duration      206529 non-null  int64
#  3   Tot Fwd Pkts       206529 non-null  int64
#  4   Tot Bwd Pkts       206529 non-null  int64
#  5   TotLen Fwd Pkts    206529 non-null  int64
#  6   TotLen Bwd Pkts    206529 non-null  float64
#  7   Fwd Pkt Len Max    206529 non-null  int64
#  8   Fwd Pkt Len Min    206529 non-null  int64
#  9   Fwd Pkt Len Mean   206529 non-null  float64
#  10  Fwd Pkt Len Std    206529 non-null  float64
#  11  Bwd Pkt Len Max    206529 non-null  int64
#  12  Bwd Pkt Len Min    206529 non-null  int64
#  13  Bwd Pkt Len Mean   206529 non-null  float64
#  14  Bwd Pkt Len Std    206529 non-null  float64
# ...

# %%
RFmodel=RF.fit(x,y.values.ravel())

# %%
Importances=RFmodel.feature_importances_

# %%
Importances
# Out:
# array([8.70401664e-02, 1.34879765e-03, 3.93914201e-02, 1.13321133e-02,
#        1.22329448e-02, 1.83191372e-02, 9.47971196e-03, 1.75107719e-02,
#        3.30383652e-04, 1.05494224e-02, 8.62784221e-03, 8.96330497e-03,
#        5.14708308e-04, 1.27231535e-02, 8.96161621e-03, 1.78229585e-02,
#        2.92981901e-02, 3.05065331e-02, 6.89446915e-03, 3.09108134e-02,
#        2.75155906e-02, 2.86962200e-02, 2.26291270e-02, 3.31680702e-03,
#        2.65345134e-02, 2.93331992e-02, 2.26271351e-03, 2.20105531e-03,
#        4.00659774e-03, 3.93079863e-03, 4.63814243e-03, 3.31056007e-04,
#        2.42748996e-05, 4.85062221e-02, 1.59460583e-02, 2.66201981e-02,
#        2.05874734e-02, 8.24608700e-04, 1.38864473e-02, 1.12264525e-02,
#        9.87198002e-03, 7.40412717e-03, 1.62879494e-04, 9.29883936e-05,
#        5.22897524e-03, 6.34725557e-03, 4.18953537e-03, 1.59508287e-03,
#        3.22895424e-05, 4.62563339e-03, 2.02353745e-03, 1.34133995e-02,
# ...

# %%
print(*enumerate(Importances), sep='\n')
# Out:
# (0, 0.08704016638157813)
# (1, 0.0013487976471528115)
# (2, 0.03939142009807335)
# (3, 0.011332113314907313)
# (4, 0.012232944845115801)
# (5, 0.01831913723592205)
# (6, 0.009479711958649644)
# (7, 0.017510771932980947)
# (8, 0.0003303836517209255)
# (9, 0.010549422441560968)
# (10, 0.008627842208377366)
# (11, 0.008963304966896422)
# (12, 0.0005147083081461795)
# (13, 0.012723153483817487)
# (14, 0.008961616206483572)
# (15, 0.01782295846885447)
# (16, 0.02929819010921777)
# (17, 0.030506533099852833)
# (18, 0.006894469152030561)
# (19, 0.03091081339755744)
# (20, 0.027515590633377288)
# (21, 0.028696220014622766)
# (22, 0.02262912699126892)
# (23, 0.0033168070227639905)
# (24, 0.026534513386519104)
# (25, 0.0293331991987496)
# (26, 0.0022627135124835226)
# (27, 0.0022010553073860944)
# (28, 0.0040065977350462354)
# (29, 0.003930798627191309)
# (30, 0.004638142434764245)
# (31, 0.000331056007425097)
# (32, 2.427489963708207e-05)
# (33, 0.04850622207945492)
# ...

# %%
x.columns
# Out:
# Index(['Dst Port', 'Protocol', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max',
#        'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std',
#        'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean',
#        'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean',
#        'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot',
#        'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min',
#        'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max',
#        'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd URG Flags', 'Fwd Header Len',
#        'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min',
#        'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var',
#        'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt',
#        'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt',
# ...

# %%
colList=list(x.columns)

# %%
print(*enumerate(colList), sep='\n')
# Out:
# (0, 'Dst Port')
# (1, 'Protocol')
# (2, 'Flow Duration')
# (3, 'Tot Fwd Pkts')
# (4, 'Tot Bwd Pkts')
# (5, 'TotLen Fwd Pkts')
# (6, 'TotLen Bwd Pkts')
# (7, 'Fwd Pkt Len Max')
# (8, 'Fwd Pkt Len Min')
# (9, 'Fwd Pkt Len Mean')
# (10, 'Fwd Pkt Len Std')
# (11, 'Bwd Pkt Len Max')
# (12, 'Bwd Pkt Len Min')
# (13, 'Bwd Pkt Len Mean')
# (14, 'Bwd Pkt Len Std')
# (15, 'Flow Byts/s')
# (16, 'Flow Pkts/s')
# (17, 'Flow IAT Mean')
# (18, 'Flow IAT Std')
# (19, 'Flow IAT Max')
# (20, 'Flow IAT Min')
# (21, 'Fwd IAT Tot')
# (22, 'Fwd IAT Mean')
# (23, 'Fwd IAT Std')
# (24, 'Fwd IAT Max')
# (25, 'Fwd IAT Min')
# (26, 'Bwd IAT Tot')
# (27, 'Bwd IAT Mean')
# (28, 'Bwd IAT Std')
# (29, 'Bwd IAT Max')
# (30, 'Bwd IAT Min')
# (31, 'Fwd PSH Flags')
# (32, 'Fwd URG Flags')
# (33, 'Fwd Header Len')
# (34, 'Bwd Header Len')
# (35, 'Fwd Pkts/s')
# (36, 'Bwd Pkts/s')
# (37, 'Pkt Len Min')
# (38, 'Pkt Len Max')
# (39, 'Pkt Len Mean')
# (40, 'Pkt Len Std')
# (41, 'Pkt Len Var')
# (42, 'FIN Flag Cnt')
# ...

# %%
x.drop(['Protocol', 'Fwd Pkt Len Min', 'Bwd Pkt Len Min', 'Fwd PSH Flags', 'Fwd URG Flags', 'Pkt Len Min', 'SYN Flag Cnt', 'CWE Flag Count', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Std'], axis=1, inplace=True)

# %%
x.columns
# Out:
# Index(['Dst Port', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max',
#        'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max',
#        'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd Header Len', 'Bwd Header Len',
#        'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Max', 'Pkt Len Mean',
#        'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'RST Flag Cnt',
#        'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'ECE Flag Cnt',
#        'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg',
#        'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts',
# ...

# %%
colList=list(x.columns)
print(*enumerate(colList), sep='\n')
# Out:
# (0, 'Dst Port')
# (1, 'Flow Duration')
# (2, 'Tot Fwd Pkts')
# (3, 'Tot Bwd Pkts')
# (4, 'TotLen Fwd Pkts')
# (5, 'TotLen Bwd Pkts')
# (6, 'Fwd Pkt Len Max')
# (7, 'Fwd Pkt Len Mean')
# (8, 'Fwd Pkt Len Std')
# (9, 'Bwd Pkt Len Max')
# (10, 'Bwd Pkt Len Mean')
# (11, 'Bwd Pkt Len Std')
# (12, 'Flow Byts/s')
# (13, 'Flow Pkts/s')
# (14, 'Flow IAT Mean')
# (15, 'Flow IAT Std')
# (16, 'Flow IAT Max')
# (17, 'Flow IAT Min')
# (18, 'Fwd IAT Tot')
# (19, 'Fwd IAT Mean')
# (20, 'Fwd IAT Std')
# (21, 'Fwd IAT Max')
# (22, 'Fwd IAT Min')
# (23, 'Bwd IAT Tot')
# (24, 'Bwd IAT Mean')
# (25, 'Bwd IAT Std')
# (26, 'Bwd IAT Max')
# (27, 'Bwd IAT Min')
# (28, 'Fwd Header Len')
# (29, 'Bwd Header Len')
# (30, 'Fwd Pkts/s')
# (31, 'Bwd Pkts/s')
# (32, 'Pkt Len Max')
# (33, 'Pkt Len Mean')
# (34, 'Pkt Len Std')
# (35, 'Pkt Len Var')
# (36, 'FIN Flag Cnt')
# (37, 'RST Flag Cnt')
# (38, 'PSH Flag Cnt')
# (39, 'ACK Flag Cnt')
# (40, 'URG Flag Cnt')
# (41, 'ECE Flag Cnt')
# (42, 'Down/Up Ratio')
# ...

# %%
corr_matrix = x.corr()
for col in colList:
    print(corr_matrix[col].sort_values(ascending=False))
# Out:
# Dst Port             1.000000
# Fwd Pkt Len Std      0.464863
# Fwd Pkt Len Max      0.374197
# ACK Flag Cnt         0.336661
# Fwd Seg Size Avg     0.322665
# Fwd Pkt Len Mean     0.322665
# URG Flag Cnt         0.254910
# Init Fwd Win Byts    0.250144
# Fwd Seg Size Min     0.182722
# RST Flag Cnt         0.148407
# ECE Flag Cnt         0.148388
# Pkt Len Std          0.143282
# Pkt Len Max          0.104662
# Fwd Pkts/s           0.101177
# Flow IAT Min         0.091943
# Fwd IAT Min          0.087751
# Flow IAT Mean        0.085747
# Pkt Len Var          0.084034
# Flow Byts/s          0.083320
# Fwd IAT Mean         0.080680
# Init Bwd Win Byts    0.066094
# Idle Min             0.064951
# Idle Mean            0.061690
# FIN Flag Cnt         0.059104
# Idle Max             0.058484
# Fwd IAT Max          0.045493
# Flow IAT Max         0.039432
# Flow Pkts/s          0.038256
# Pkt Len Mean         0.015836
# Pkt Size Avg         0.013083
# TotLen Fwd Pkts     -0.007181
# ...

# %%
x.drop(['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Seg Size Avg', 'Bwd Pkt Len Max', 'Bwd Pkt Len Mean', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Std', 'Fwd Header Len', 'Bwd Header Len', 'Pkt Len Max', 'Pkt Len Mean', 'RST Flag Cnt', 'Subflow Fwd Pkts', 'Subflow Bwd Pkts', 'Idle Mean'], axis=1, inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206529 entries, 352042 to 1259943
# Data columns (total 35 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           206529 non-null  int64
#  1   Fwd Pkt Len Mean   206529 non-null  float64
#  2   Fwd Pkt Len Std    206529 non-null  float64
#  3   Bwd Pkt Len Std    206529 non-null  float64
#  4   Flow Byts/s        206529 non-null  float64
#  5   Flow Pkts/s        206529 non-null  float64
#  6   Fwd IAT Tot        206529 non-null  float64
#  7   Fwd IAT Mean       206529 non-null  float64
#  8   Fwd IAT Max        206529 non-null  float64
#  9   Fwd IAT Min        206529 non-null  float64
#  10  Bwd IAT Tot        206529 non-null  float64
#  11  Bwd IAT Mean       206529 non-null  float64
#  12  Bwd IAT Std        206529 non-null  float64
#  13  Bwd IAT Max        206529 non-null  float64
#  14  Bwd IAT Min        206529 non-null  float64
# ...

# %%
x.shape
# Out:
# (206529, 35)

# %%
y.shape
# Out:
# (206529, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (165223, 35)

# %%
 x_test.shape
# Out:
# (41306, 35)

# %%
y_train.shape
# Out:
# (165223, 1)

# %%
y_test.shape
# Out:
# (41306, 1)

# %%
from sklearn import svm

# %%
from sklearn.preprocessing import QuantileTransformer

# %%
qt = QuantileTransformer()

# %%
x_train = qt.fit_transform(x_train)

# %%
x_test = qt.fit_transform(x_test)

# %%
# %%time
classifier = svm.SVC(kernel='linear', C=1, max_iter=-1, tol=0.001).fit(x_train, y_train.values.ravel())
# Out:
# Wall time: 1min 31s

# %%
classifier.score(x_test, y_test.values.ravel())
# Out:
# 0.9567133104149518

# %%
# %%time
y_pred = classifier.predict(x_test)
# Out:
# Wall time: 27 s

# %%
y_pred
# Out:
# array([1, 7, 7, ..., 7, 7, 7], dtype=int64)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 3423,     0,     0,     0,     0,     0,     0],
#        [    0,  2635,   628,     0,     0,     0,     0],
#        [    0,   108,  1806,     0,     0,     0,     0],
#        [    0,     0,     0,  1267,     0,     0,   109],
#        [    5,     3,     0,     4,     0,     0,   811],
#        [    0,     0,     0,     0,     0,     0,     4],
#        [   20,    33,     0,    62,     1,     0, 30387]], dtype=int64)

# %%
classification_report(y_test, y_pred)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# '              precision    recall  f1-score   support\n\n           1       0.99      1.00      1.00      3423\n           2       0.95      0.81      0.87      3263\n           3       0.74      0.94      0.83      1914\n           4       0.95      0.92      0.94      1376\n           5       0.00      0.00      0.00       823\n           6       0.00      0.00      0.00         4\n           7       0.97      1.00      0.98     30503\n\n    accuracy                           0.96     41306\n   macro avg       0.66      0.67      0.66     41306\nweighted avg       0.94      0.96      0.95     41306\n'

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9567133104149518
